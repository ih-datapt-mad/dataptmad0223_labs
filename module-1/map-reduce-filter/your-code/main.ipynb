# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas

# %%
from functools import reduce
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')
print(prophet[0:10])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'The', 'Prophet,', 'by', 'Kahlil', 'Gibran\n\nThis']

# %%
len (prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
#CÓDIGO
words_delete = [prophet[0:568]] #he creado esta variable para guardar las palabras que posteriormente elimino.
print (len(words_delete))
print(len(prophet))
new_prophet = prophet  #he creado esta variable para no perder la original
del new_prophet[0:568] #
print(len(new_prophet))
# Out:
# 1
# 13637
# 13069

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# RESPUESTA
print(new_prophet[0:10])
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # your code here 

    x_mod= x.split("{", 1)[0]
    return x_mod

# %%
new_prophet_str= str(new_prophet)
print(reference(new_prophet_str[0:50]))
# Out:
# ['PROPHET\n\n|Almustafa,', 'the

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
#RESPUESTA
map(reference, prophet) #Hago un map sobre la función reference creada ahora y el libro que teniamos
prophet_reference= list(map(reference, prophet))  #creo nueva variable que guarde este resultado
print(prophet_reference[0:30]) #He delimitado porque el libro es muy largo
# Out:
# ['PROPHET\n\n|Almustafa,', 'the', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto', 'his', 'own\nday,', 'had', 'waited', 'twelve', 'years', 'in', 'the', 'city\nof', 'Orphalese', 'for', 'his', 'ship', 'that', 'was', 'to\nreturn', 'and', 'bear', 'him', 'back']

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # your code here
    x_mod= x.split("\n")
    return x_mod

# %%
new_prophet_str= str(new_prophet)
print(line_break(new_prophet_str[0:50]))
#REALMENTE NO SÉ SI LA SOLUCIÓN ES CORRECTA
# Out:
# ["['PROPHET\\n\\n|Almustafa,', 'the{7}', 'chosen', 'an"]

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
prophet_line = list(map(line_break,prophet_reference))
print(prophet_line[0:30])
# Out:
# [['PROPHET', '', '|Almustafa,'], ['the'], ['chosen'], ['and'], ['the', 'beloved,'], ['who'], ['was'], ['a'], ['dawn'], ['unto'], ['his'], ['own', 'day,'], ['had'], ['waited'], ['twelve'], ['years'], ['in'], ['the'], ['city', 'of'], ['Orphalese'], ['for'], ['his'], ['ship'], ['that'], ['was'], ['to', 'return'], ['and'], ['bear'], ['him'], ['back']]

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
#Respuesta
prophet_flat = [i for i in prophet_line]
print(prophet_flat[0:30])
# Out:
# [['PROPHET', '', '|Almustafa,'], ['the'], ['chosen'], ['and'], ['the', 'beloved,'], ['who'], ['was'], ['a'], ['dawn'], ['unto'], ['his'], ['own', 'day,'], ['had'], ['waited'], ['twelve'], ['years'], ['in'], ['the'], ['city', 'of'], ['Orphalese'], ['for'], ['his'], ['ship'], ['that'], ['was'], ['to', 'return'], ['and'], ['bear'], ['him'], ['back']]

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    word_list = ['and', 'the', 'a', 'an']
    for y in word_list:
        if y in x:
            return False
    return True
    # your code here

# %%
print(word_filter(new_prophet[0:30]))
# Out:
# False

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
filter(word_filter,new_prophet)
prophet_filter = list (filter(word_filter,new_prophet[0:30]))
print(prophet_filter)
# Out:
# ['chosen', 'who', 'unto', 'his', 'twelve', 'in', 'city\nof', 'for', 'his', 'ship', 'to\nreturn', 'him']

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_nocase_sensitive(x):
    word_list = ['and', 'the', 'a', 'an']
    x = x.upper() 
    for y in word_list:
        if y.upper() in x:
            return False
    return True

# %%
palabras = ['azul', 'manzana', 'carro', 'elefante', 'feliz', 'guitarra','AND']
print(word_filter_nocase_sensitive(str(palabras)))
# Out:
# False

# %%
print(word_filter_nocase_sensitive(str(new_prophet)))
# Out:
# False

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    return a + " " + b

    # your code here

# %%
resultado_string= reduce(concat_space, prophet_filter)   #reduce hace lo que pide la función sobre la lista
print(resultado_string)
# Out:
# chosen who unto his twelve in city
# of for his ship to
# return him

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
#resultado
prophet_string= resultado_string.replace("\n", " ")
print(prophet_string)
# Out:
# chosen who unto his twelve in city of for his ship to return him

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will connect to Ironhack's database and retrieve the data from the *pollution* database. Select the *beijing_pollution* table and retrieve its data.

# %%
# MI CÓDIGO. 
#Solo me he descargado el fichero CSV que corresponde a la tabla beijin_pollution.
#Lo he abierto y guardado el contenido en lines.
with open('//Users/herminiapadialromera/ironhackb/dataptmad0223_labs/module-1/map-reduce-filter/PRSA_data_2010.1.1-2014.12.31.csv') as f:
    lines = f.readlines()
lines
# Out:
# ['No,year,month,day,hour,pm2.5,DEWP,TEMP,PRES,cbwd,Iws,Is,Ir\n',
#  '1,2010,1,1,0,NA,-21,-11,1021,NW,1.79,0,0\n',
#  '2,2010,1,1,1,NA,-21,-12,1020,NW,4.92,0,0\n',
#  '3,2010,1,1,2,NA,-21,-11,1019,NW,6.71,0,0\n',
#  '4,2010,1,1,3,NA,-21,-14,1019,NW,9.84,0,0\n',
#  '5,2010,1,1,4,NA,-20,-12,1018,NW,12.97,0,0\n',
#  '6,2010,1,1,5,NA,-19,-10,1017,NW,16.1,0,0\n',
#  '7,2010,1,1,6,NA,-19,-9,1017,NW,19.23,0,0\n',
#  '8,2010,1,1,7,NA,-19,-9,1017,NW,21.02,0,0\n',
#  '9,2010,1,1,8,NA,-19,-9,1017,NW,24.15,0,0\n',
#  '10,2010,1,1,9,NA,-20,-8,1017,NW,27.28,0,0\n',
#  '11,2010,1,1,10,NA,-19,-7,1017,NW,31.3,0,0\n',
#  '12,2010,1,1,11,NA,-18,-5,1017,NW,34.43,0,0\n',
#  '13,2010,1,1,12,NA,-19,-5,1015,NW,37.56,0,0\n',
#  '14,2010,1,1,13,NA,-18,-3,1015,NW,40.69,0,0\n',
#  '15,2010,1,1,14,NA,-18,-2,1014,NW,43.82,0,0\n',
#  '16,2010,1,1,15,NA,-18,-1,1014,cv,0.89,0,0\n',
#  '17,2010,1,1,16,NA,-19,-2,1015,NW,1.79,0,0\n',
#  '18,2010,1,1,17,NA,-18,-3,1015,NW,2.68,0,0\n',
# ...

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# your code here

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    division24 = x / 24
    return division24
    # your code here

# %%
hourly(48)
# Out:
# 2.0

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
#He utilizado usecols porque con column daba error así que he tenido que buscar.
#creo un data frame que haga referencia a la parte que quiero seleccionar del archivo.
#con este data frame llamo a la función
df= pd.read_csv('//Users/herminiapadialromera/ironhackb/dataptmad0223_labs/module-1/map-reduce-filter/PRSA_data_2010.1.1-2014.12.31.csv', usecols=['Iws', 'Is', 'Ir'])

# %%
pm25_hourly= hourly(df)
pm25_hourly
# aquí en la variable que nos indica guardo directamente la función con el df anterior.
# Out:
#              Iws   Is   Ir
# 0       0.074583  0.0  0.0
# 1       0.205000  0.0  0.0
# 2       0.279583  0.0  0.0
# 3       0.410000  0.0  0.0
# 4       0.540417  0.0  0.0
# ...          ...  ...  ...
# 43819   9.665417  0.0  0.0
# 43820   9.907500  0.0  0.0
# 43821  10.112500  0.0  0.0
# 43822  10.280000  0.0  0.0
# 43823  10.410417  0.0  0.0
#
# [43824 rows x 3 columns]

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # your code here
    deviation= x.std()
    element= x.count()
    result= deviation / element
    return result

# %%
#solución 1: no me da el output que pone en la descripción de la función.

call_1= sample_sd(pd.Series([1,2,3,4]))
print(call_1)
# Out:
# 0.3227486121839514

# %%
def sample_sd2(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962
    '''
    
    # your code here
    deviation= x.std()
    element= x.count()-1
    result= deviation / element
    return result

# %%
#propuesta Solución2: tampoco consigo el resultado correcto. 
#Aquí lo intento aplicando el "-1" que referían arriba.
call_1= sample_sd2(pd.Series([1,2,3,4]))
print(call_1)
# Out:
# 0.4303314829119352
